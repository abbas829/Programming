# %% [markdown]
# # **Exploratery Data Analysis**

# %% [markdown]
# ## **1. Importing the installed Libraries**

# %%
import pandas as pd # for data manipulation 
import numpy as np  # for numerical operations
import seaborn as sns # for data visualization
import matplotlib.pyplot as plt # for plotting graphs
# %matplotlib inline  
# to display the graphs 
sns.set(color_codes=True) # adds a nice background to the graphs

# %% [markdown]
# # **Key Features of Pandas**
# - **DataFrame:** A two-dimensional labeled data structure for working with tabular data.
# - **Data Manipulation:** Powerful tools for filtering, transforming, and aggregating data.
# - **Data Cleaning:** Functions to handle missing values, duplicate data, and outliers.
# - **Data Input/Output:** Read and write data from various file formats, including CSV and Exc

# %% [markdown]
# # **Key Features of Numpy**
# - **dimensional arrays:** Powerful support for multi-dimensional arrays.
# - **Vectorized operations:** Efficient element-wise operations without explicit looping.
# - **Fast and memory efficient:** Designed to be fast, memory efficient and easy to use
# - **Supports a wide range of datatypes:** Includes support for integers, floating point num -bers, complex numbers, strings, boole

# %% [markdown]
# # **key Features of Seaborn**
# - **Statistical data visualization:** Seaborn provides a high-level interface for creating informative and attractive statistical graphics.
# - **Built-in themes and color palettes:** It offers a variety of aesthetic options to customize plots, including different themes and color palettes, enhancing the visual appeal of visualizations.
# - **Integration with pandas:** Seaborn seamlessly works with pandas DataFrames, allowing for easy manipulation and visualization of data stored in tabular format.
# - **Flexible plotting functions:** Seaborn provides a rich set of plotting functions for creating various types of statistical plots, such as scatter plots, bar plots, box plots, violin plots, and more.

# %% [markdown]
# # **Key Features of Matplotlib**
#
# - **Versatile plotting:** Matplotlib offers a wide range of plot types and customization options, allowing users to create various types of plots tailored to their needs.
# - **Publication-quality output:** Matplotlib produces high-quality plots suitable for publication, with extensive control over plot aesthetics and formatting.
# - **Multiple interfaces:** Matplotlib provides multiple interfaces for creating plots, including a MATLAB-style scripting interface and an object-oriented API, catering to different user preferences and levels of expertise.
# - **Integration with Jupyter Notebooks:** Matplotlib seamlessly integrates with Jupyter Notebooks, enabling interactive plotting and data visualization within the notebook environment for streamlined exploratory data analysis.

# %% [markdown]
# ---

# %% [markdown]
# ## **Loading the dataset**

# %%
df = pd.read_csv("data.csv")
# To display the top 5 rows
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.tail(5)  # To display the last 5 rows of the dataframe
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## **Checking the types of data**

# %% [markdown]
# Here we check for the datatypes because sometimes data be stored as a string, if in that case, we have to convert that string to the integer data only then we can plot the data via a graph.

# %%
df.dtypes # To check the data type of each column in the dataframe
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## **Dropping irrelevant columns**

# %% [markdown]
# This step is certainly needed in every EDA because sometimes there would be many columns that we never use in such cases dropping is the only solution.

# %%
df = df.drop(['Vehicle Size'], axis=1) # dropping the column 'Vehicle Size' from the dataframe
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Style  highway MPG  city mpg  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## **Renaming the columns**

# %% [markdown]
# Most of the column names are very confusing to read, so I just tweaked their column names. This is a good approach it improves the readability of the data set.

# %%
# rename the columns
df = df.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price" })
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type     HP  Cylinders  \
# 0  BMW  1 Series M  2011  premium unleaded (required)  335.0        6.0
# 1  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 2  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 3  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
# 4  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
#
#   Transmission        Drive Mode  Number of Doors  \
# 0       MANUAL  rear wheel drive              2.0
# 1       MANUAL  rear wheel drive              2.0
# 2       MANUAL  rear wheel drive              2.0
# 3       MANUAL  rear wheel drive              2.0
# 4       MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Style  MPG-H  MPG-C  \
# 0  Factory Tuner,Luxury,High-Performance         Coupe     26     19
# 1                     Luxury,Performance   Convertible     28     19
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## **Dropping the duplicate rows**

# %% [markdown]
# This is often a handy thing to do because a huge data set have some duplicate data which might be disturbing, so here we remove all the duplicate value from the data-set.

# %%
df.shape
# Number of rows and columns
# Out:
# (11914, 15)

# %%
duplicate_rows_df = df[df.duplicated()]
# Displaying the duplicate rows in the dataframe
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (726, 15)

# %% [markdown]
# Now let us remove the duplicate data because it's ok to remove them.

# %%
# remove the duplicate rows
df = df.drop_duplicates()

# %%
# check again duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (11188, 15)

# %% [markdown]
# ## **Counting the number of Rows**

# %%
df.count()      # Used to count the number of rows
# Out:
# Make                11188
# Model               11188
# Year                11188
# Engine Fuel Type    11185
# HP                  11119
# Cylinders           11158
# Transmission        11188
# Drive Mode          11188
# Number of Doors     11182
# Market Category      7823
# Vehicle Style       11188
# MPG-H               11188
# MPG-C               11188
# Popularity          11188
# Price               11188
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## **Dropping the missing or null values.**

# %% [markdown]
# This is mostly similar to the previous step but in here all the missing values are detected and are dropped later. Now, this is not a good approach to do so, because many people just replace the missing values with the mean or the average of that column, but in this case, I just dropped that missing values.

# %%
print(df.isnull().sum()) # To count the number of missing values in each column
# Out:
# Make                   0
# Model                  0
# Year                   0
# Engine Fuel Type       3
# HP                    69
# Cylinders             30
# Transmission           0
# Drive Mode             0
# Number of Doors        6
# Market Category     3365
# Vehicle Style          0
# MPG-H                  0
# MPG-C                  0
# Popularity             0
# Price                  0
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.

# %%
# check again the number of missing values in each column
df.isnull().sum()
# Out:
# Make                0
# Model               0
# Year                0
# Engine Fuel Type    0
# HP                  0
# Cylinders           0
# Transmission        0
# Drive Mode          0
# Number of Doors     0
# Market Category     0
# Vehicle Style       0
# MPG-H               0
# MPG-C               0
# Popularity          0
# Price               0
# dtype: int64

# %% [markdown]
# Now we have removed all the rows which contain the Null or N/A values.

# %% [markdown]
# ---

# %% [markdown]
# ## **Detecting Outliers**

# %% [markdown]
# An outlier is a point or set of points that are different from other points. Sometimes they can be very high or very low. It's often a good idea to detect and remove the outliers. Because outliers are one of the primary reasons for resulting in a less accurate model. Hence it's a good idea to remove them. The outlier detection and removing that we are going to perform is called IQR score technique. Often outliers can be seen with visualizations using a box plot.

# %%
sns.boxplot(x=df['Price'])
# boxplot for 'Price' column of the dataframe df
# Out:
# <Axes: xlabel='Price'>

# %%
sns.boxplot(x=df['HP'])
# boxplot for 'HP' column of the dataframe df
# Out:
# <Axes: xlabel='HP'>

# %%
sns.boxplot(x=df['Cylinders'])
# boxplot for 'Cylinders' column of the dataframe df
# Out:
# <Axes: xlabel='Cylinders'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7735 entries, 0 to 11913
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Make              7735 non-null   object
#  1   Model             7735 non-null   object
#  2   Year              7735 non-null   int64
#  3   Engine Fuel Type  7735 non-null   object
#  4   HP                7735 non-null   float64
#  5   Cylinders         7735 non-null   float64
#  6   Transmission      7735 non-null   object
#  7   Drive Mode        7735 non-null   object
#  8   Number of Doors   7735 non-null   float64
#  9   Market Category   7735 non-null   object
#  10  Vehicle Style     7735 non-null   object
#  11  MPG-H             7735 non-null   int64
#  12  MPG-C             7735 non-null   int64
#  13  Popularity        7735 non-null   int64
#  14  Price             7735 non-null   int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 966.9+ KB

# %%
# finding the IQR 
# Select only numeric columns
numeric_columns = df.select_dtypes(include='number')

# Compute the interquartile range (IQR) for numeric columns
Q1 = numeric_columns.quantile(0.25)  # 25th percentile
Q3 = numeric_columns.quantile(0.75)  # 75th percentile
IQR = Q3 - Q1
IQR = Q3 - Q1
print(IQR)
# Out:
# Year                   6.0
# HP                   131.0
# Cylinders              2.0
# Number of Doors        2.0
# MPG-H                  8.0
# MPG-C                  6.0
# Popularity          1489.0
# Price              23252.5
# dtype: float64

# %% [markdown]
# ## **4.0. Correlation of different features**

# %%
# Select only numeric columns
numeric_columns = df.select_dtypes(include='number')

# Compute the correlation matrix for numeric columns
numeric_columns.corr()
# Out:
#                      Year        HP  Cylinders  Number of Doors     MPG-H  \
# Year             1.000000  0.234461  -0.051369         0.189846  0.219893
# HP               0.234461  1.000000   0.811138        -0.212644 -0.468328
# Cylinders       -0.051369  0.811138   1.000000        -0.192441 -0.597864
# Number of Doors  0.189846 -0.212644  -0.192441         1.000000  0.114555
# MPG-H            0.219893 -0.468328  -0.597864         0.114555  1.000000
# MPG-C            0.183083 -0.510151  -0.613399         0.150835  0.818331
# Popularity       0.126803  0.036553   0.010051        -0.042345  0.033672
# Price            0.125162  0.655522   0.589557        -0.193079 -0.255595
#
#                     MPG-C  Popularity     Price
# Year             0.183083    0.126803  0.125162
# HP              -0.510151    0.036553  0.655522
# Cylinders       -0.613399    0.010051  0.589557
# Number of Doors  0.150835   -0.042345 -0.193079
# MPG-H            0.818331    0.033672 -0.255595
# ...

# %% [markdown]
# ## 9. Plot different features against one another (scatter), against frequency (histogram)

# %% [markdown]
# ### Histogram
#
# Histogram refers to the frequency of occurrence of variables in an interval. In this case, there are mainly 10 different types of car manufacturing companies, but it is often important to know who has the most number of cars. To do this histogram is one of the trivial solutions which lets us know the total number of car manufactured by a different company.

# %% [markdown]
# ## **Price vs Make**

# %%
# Plotting the distribution of cars by make 
df.Make.value_counts().nlargest(15).plot(kind='bar', figsize=(10,5)) 
plt.title("Price of cars by make")
plt.ylabel('price of cars')
plt.xlabel('Make');

# %% [markdown]
# ## **Number of Cars vs Make**

# %%
# Plotting the distribution of cars by make
df.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make');

# %% [markdown]
# ## **Data vs the Year**

# %%
# Plotting the distribution of cars by year 
plt.figure(figsize=(10,10))
df.Year.value_counts().plot(kind='pie')
plt.show()

# %%
df.Make.value_counts().nlargest(20).plot(kind='bar', figsize=(15, 10)) # figsize=(15, 10)
plt.title("Number of HP by car")
plt.ylabel('Number of HP')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %% [markdown]
# ## **5.0. Heat Maps**

# %%
# Adjusting the Size of Figure
plt.figure(figsize=(10,5))
# calculating the Correlation
correlation = numeric_columns.corr()
# Displaying the correlation using the Heap Map
sns.heatmap(correlation,cmap="BrBG",annot=True) # Br: Brown. B: Blue, G: Green

#correlation
# Out:
# <Axes: >
